# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("south_india.csv")
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 155.8                 191.5                 138.4
# 1    1902                 118.9                 214.4                 159.7
# 2    1903                 141.0                 300.2                 206.2
# 3    1904                 191.9                 191.4                  89.5
# 4    1905                 153.5                 120.6                 187.6
# 5    1906                 174.0                 219.9                 221.8
# 6    1907                 184.8                 206.3                 216.3
# 7    1908                 125.0                 240.1                 155.1
# 8    1909                 157.3                 227.5                 196.0
# 9    1910                 180.0                 211.1                 209.4
# 10   1911                 189.6                 191.6                 103.5
# ...

# %%
a=df[["Actual Rainfall: JUN"]]
a
# Out:
#      Actual Rainfall: JUN
# 0                   155.8
# 1                   118.9
# 2                   141.0
# 3                   191.9
# 4                   153.5
# 5                   174.0
# 6                   184.8
# 7                   125.0
# 8                   157.3
# 9                   180.0
# 10                  189.6
# 11                  144.8
# 12                  133.9
# 13                  157.6
# 14                  193.8
# 15                  199.6
# 16                  206.4
# 17                  114.4
# 18                  176.2
# 19                  169.0
# 20                  141.7
# 21                  146.8
# 22                  119.6
# 23                  161.6
# 24                  167.1
# 25                  116.3
# 26                  180.9
# 27                  153.8
# 28                  207.1
# 29                  185.8
# ..                    ...
# 86                  131.0
# 87                  127.8
# 88                  178.5
# ...

# %%
df["Actual Rainfall: JUN"].max()
# Out:
# 278.0

# %%
df.sort_values("Departure Percentage: JUN-SEPT").head()
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 17   1918                 114.4                  85.5                 123.7
# 101  2002                 151.7                  95.8                 182.0
# 51   1952                 131.1                 170.0                 150.0
# 4    1905                 153.5                 120.6                 187.6
# 71   1972                 147.8                 181.5                  92.6
#
#      Actual Rainfall: SEPT  Departure Percentage: JUN  \
# 17                   110.4                      -28.1
# 101                   77.2                       -8.0
# 51                    77.3                      -21.9
# 4                     99.0                       -4.0
# 71                   151.3                       -6.7
#
#      Departure Percentage: JUL  Departure Percentage: AUG  \
# 17                       -60.5                      -27.2
# 101                      -59.0                       -5.1
# ...

# %%
df=pd.read_csv("ne-India_rainfall_act_dep_1901_2016.csv")
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 252.3                 304.1                 364.0
# 1    1902                 276.4                 388.4                 306.4
# 2    1903                 318.1                 214.4                 374.0
# 3    1904                 294.8                 424.7                 355.1
# 4    1905                 205.0                 429.9                 445.6
# 5    1906                 257.6                 381.1                 395.6
# 6    1907                 341.5                 353.3                 297.1
# 7    1908                 257.3                 344.4                 271.8
# 8    1909                 436.7                 293.5                 420.5
# 9    1910                 357.3                 413.8                 344.6
# 10   1911                 380.0                 321.9                 377.2
# ...

# %%
df.sort_values("Departure Percentage: JUN-SEPT")['YEAR'].head()
# Out:
# 112    2013
# 108    2009
# 104    2005
# 91     1992
# 71     1972
# Name: YEAR, dtype: int64

# %%
df=pd.read_csv("nw-India_rainfall_act_dep_1901_2016.csv")
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                  22.7                 185.2                 264.1
# 1    1902                  59.9                 225.2                 143.8
# 2    1903                  26.2                 211.7                 275.2
# 3    1904                  53.4                 253.7                 234.0
# 4    1905                  23.1                 162.9                 128.3
# 5    1906                  91.8                 200.5                 249.1
# 6    1907                  41.4                 121.3                 274.5
# 7    1908                  41.1                 306.5                 366.9
# 8    1909                 125.0                 324.0                 234.3
# 9    1910                 116.9                 187.0                 298.3
# 10   1911                  78.0                  59.0                 150.4
# ...

# %%
df.sort_values("Departure Percentage: JUN-SEPT")['YEAR'].head()
# Out:
# 17     1918
# 86     1987
# 78     1979
# 108    2009
# 64     1965
# Name: YEAR, dtype: int64

# %%
df=pd.read_csv("central-India_rainfall_act_dep_1901_2016.csv")
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                  99.3                 295.4                 354.8
# 1    1902                  62.3                 334.2                 237.6
# 2    1903                  96.2                 392.7                 286.6
# 3    1904                 180.5                 259.1                 200.9
# 4    1905                  59.8                 340.6                 178.9
# 5    1906                 221.9                 361.9                 234.0
# 6    1907                 151.9                 270.1                 407.0
# 7    1908                 148.6                 401.3                 384.4
# 8    1909                 210.4                 375.3                 197.5
# 9    1910                 243.4                 255.6                 326.7
# 10   1911                 213.0                 159.5                 267.5
# ...

# %%
df.sort_values("Departure Percentage: JUN-SEPT").head()
# Out:
#     YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 17  1918                 199.7                 157.0                 238.8
# 86  1987                 103.3                 209.4                 259.7
# 73  1974                  90.2                 227.2                 285.9
# 71  1972                 116.0                 216.9                 297.2
# 19  1920                 147.3                 338.5                 176.2
#
#     Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 17                   84.4                      679.9
# 86                  111.2                      683.6
# 73                   99.9                      703.2
# 71                  124.9                      754.9
# 19                   98.1                      760.1
#
#     Departure Percentage: JUN  Departure Percentage: JUL  \
# 17                       18.1                      -55.4
# 86                      -33.0                      -37.7
# ...
