# %%
import pandas as pd
df=pd.read_csv("south_india.csv")
df.sort_values("Departure Percentage: JUN-SEPT",ascending=False)['YEAR'].head(1)
# Out:
# 82    1983
# Name: YEAR, dtype: int64

# %%
df=pd.read_csv("ne-India_rainfall_act_dep_1901_2016.csv")
df.sort_values("Departure Percentage: JUN-SEPT",ascending=False)['YEAR'].head(1)
# Out:
# 86    1987
# Name: YEAR, dtype: int64

# %%
df=pd.read_csv("nw-India_rainfall_act_dep_1901_2016.csv")
df.sort_values("Departure Percentage: JUN-SEPT",ascending=False)['YEAR'].head(1)
# Out:
# 16    1917
# Name: YEAR, dtype: int64

# %%
df=pd.read_csv("central-India_rainfall_act_dep_1901_2016.csv")
df.sort_values("Departure Percentage: JUN-SEPT",ascending=False)['YEAR'].head(1)
# Out:
# 60    1961
# Name: YEAR, dtype: int64

# %%
file = 'METEOROLOGICAL_SUB_DIVISION_WISE_ANNUAL_RAINFALL.xls'
mfile = pd.read_excel(file)
mfile
# Out:
#                             Sub-division  2002 (in millimetre)  \
# 0            Andaman and Nicobar Islands                2310.7
# 1                      Arunachal Pradesh                2559.6
# 2                    Assam and Meghalaya                2530.4
# 3   Nagaland,Mizoram,Manipur and Tripura                1960.8
# 4    Sub-Himalayan,West Bengal & Sikkim                 2820.1
# 5                   Gangetic West Bengal                1597.5
# 6                                 Orissa                1166.6
# 7                              Jharkhand                1315.5
# 8                                 Bihar                 1193.3
# 9                     Uttar Pradesh East                 796.0
# 10                    Uttar Pradesh West                 729.1
# 11                           Uttranchal                 1588.5
# 12            Haryana,Chandigarh & Delhi                 471.8
# 13                                Punjab                 446.1
# ...

# %%
mfile = pd.read_excel(file)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sub-division'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-d7f679b91e61> in <module>()
# ----> 1 df['Sub-division']
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('', index_col = False)


#plot data
plt.plot(data['Year'], data['Product 1'], linestyle="dotted", marker='^', color="red", label = 'Product 1')

plt.plot(data['Year'], data['Product 2'], linestyle="solid", marker='o', color="green", label = 'Product 2')

plt.plot(data['Year'], data['Product 3'], linestyle="dashed", marker='<', color="blue", label = 'Product 3')



#labels
plt.xlabel("Year")
plt.ylabel("Number in units")

# add legend
plt.legend()

#title
plt.title("Poduct Analysis")

# save plot as image
plt.savefig('products.jpg')
